# %%
import pandas as pd

hr_data = pd.read_csv('data/data_pegawai_hr_project.csv')

hr_data.head()
# Out:
#          Nama Pegawai     Gender Tanggal Masuk Tanggal Resign  Status  \
# 0         Steven Reid  Laki-laki      7/5/2023            NaN   Aktif
# 1      Sandra Johnson  Laki-laki      3/8/2024            NaN   Aktif
# 2  Cassandra Anderson  Perempuan     8/12/2023            NaN   Aktif
# 3      Nicholas Smith  Laki-laki     12/1/2020            NaN   Aktif
# 4     Jennifer Walton  Perempuan      1/7/2023       4/5/2024  Resign
#
#   Department       Jabatan  Performance (1-5)  Jumlah Promosi  \
# 0    Finance  Senior Staff                  1               2
# 1         HR  Senior Staff                  1               0
# 2    Finance       Manager                  5               3
# 3         IT    Supervisor                  2               3
# 4         IT    Supervisor                  4               0
#
#                                          Feedback
# 0   Terlalu banyak tekanan kerja tanpa apresiasi.
# 1             Saya sangat senang bekerja di sini.
# ...

# %%
hr_data['Tanggal Resign'] = hr_data['Tanggal Resign'].fillna('Still Working')

# %%
hr_data['Tanggal Resign'] = pd.to_datetime(hr_data['Tanggal Resign'], errors='coerce')

resign_jan_2022 = hr_data[(hr_data['Tanggal Resign'].dt.year==2024) & (hr_data['Tanggal Resign'].dt.month)== 7]

resign_jan_2022
# Out:
# C:\Users\reza\AppData\Local\Temp\ipykernel_7336\2946822834.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   hr_data['Tanggal Resign'] = pd.to_datetime(hr_data['Tanggal Resign'], errors='coerce')
# Empty DataFrame
# Columns: [Nama Pegawai, Gender, Tanggal Masuk, Tanggal Resign, Status, Department, Jabatan, Performance (1-5), Jumlah Promosi, Feedback, Kepuasan]
# Index: []

# %%
hr_data.head()
# Out:
#          Nama Pegawai     Gender Tanggal Masuk Tanggal Resign  Status  \
# 0         Steven Reid  Laki-laki    2023-07-05  Still Working   Aktif
# 1      Sandra Johnson  Laki-laki    2024-03-08  Still Working   Aktif
# 2  Cassandra Anderson  Perempuan    2023-08-12  Still Working   Aktif
# 3      Nicholas Smith  Laki-laki    2020-12-01  Still Working   Aktif
# 4     Jennifer Walton  Perempuan    2023-01-07     2024-04-05  Resign
#
#   Department       Jabatan  Performance (1-5)  Jumlah Promosi  \
# 0    Finance  Senior Staff                  1               2
# 1         HR  Senior Staff                  1               0
# 2    Finance       Manager                  5               3
# 3         IT    Supervisor                  2               3
# 4         IT    Supervisor                  4               0
#
#                                          Feedback    Kepuasan
# 0   Terlalu banyak tekanan kerja tanpa apresiasi.  Tidak Puas
# ...

# %%
masuk_bulanan = hr_data['Tanggal Masuk'].groupby(hr_data['Tanggal Masuk'].dt.to_period('M')).count().reindex(bulan_range.to_period('M'), fill_value=0)
masuk_bulanan
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 masuk_bulanan = hr_data['Tanggal Masuk'].groupby(hr_data['Tanggal Masuk'].dt.to_period('M')).count().reindex(bulan_range.to_period('M'), fill_value=0)
#       2 masuk_bulanan
#
# File d:\REZAPROJECT\portofolio\hr-data-dashboard\myenv\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File d:\REZAPROJECT\portofolio\hr-data-dashboard\myenv\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
# ...
